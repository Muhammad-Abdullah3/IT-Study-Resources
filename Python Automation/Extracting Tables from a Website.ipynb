# %%
import pandas as pd

# %%
# We will extract tables from websites like wiki pedia, and any other websites
simpsons = pd.read_html('https://en.wikipedia.org/wiki/List_of_The_Simpsons_episodes_(seasons_1%E2%80%9320)')

# %%
len(simpsons)
# Out:
# 24

# %%
simpsons[2]
# Out:
#     No. overall  No. in season  \
# 0          14.0            1.0
# 1          15.0            2.0
# 2          16.0            3.0
# 3          16.0            3.0
# 4          16.0            3.0
# 5           NaN            NaN
# 6          17.0            4.0
# 7          18.0            5.0
# 8          19.0            6.0
# 9          20.0            7.0
# 10         21.0            8.0
# 11         22.0            9.0
# 12         23.0           10.0
# 13         24.0           11.0
# 14         25.0           12.0
# 15         26.0           13.0
# 16         27.0           14.0
# 17         28.0           15.0
# 18         29.0           16.0
# 19         30.0           17.0
# 20         31.0           18.0
# 21         32.0           19.0
# 22         33.0           20.0
# 23         34.0           21.0
# 24         35.0           22.0
#
#                                                 Title      Directed by  \
# ...

# %%
# Readin ICC Ranking from Espn Cricinfo
rankings  = pd.read_html('https://www.espncricinfo.com/rankings/icc-team-ranking')

# %%
len(rankings)
# Out:
# 5

# %%
rankings[1]
# Out:
#     Position         Team  Matches  Points  Rating
# 0          1        India       63   16835     267
# 1          2    Australia       40   10241     256
# 2          3  West Indies       49   12502     255
# 3          4      England       39    9876     253
# 4          5  New Zealand       49   12113     247
# ..       ...          ...      ...     ...     ...
# 88        89      Myanmar        9       0       0
# 89        90         Mali        6       0       0
# 90        91      Lesotho       11       0       0
# 91        92       Greece        8       0       0
# 92        93       Gambia        6       0       0
#
# [93 rows x 5 columns]
